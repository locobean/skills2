# %%
#Sparta Education: Python for Data -  Final Project - Liam O'Connor 
# List the available Seaborn datasets
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# Import required libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load dataset
#penguins = pd.read_csv("penguins.csv") to load dataset form a file
penguins = sns.load_dataset("penguins").dropna() #load penguin dataset and drop NaN
penguins.head() # load first 5 rows
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %%
# Distribution of penguins by species and island
# Countplot
plt.figure(figsize=(6,4)) #Set plot canvas size
sns.countplot(data=penguins, x="species", hue="island", palette="YlGnBu") # Count of species split by island
plt.title("1.Distribution of Penguin Species") # Plot title
plt.xlabel("Species") # x-axis label
plt.ylabel("Count")   # Y-axis label
plt.show() # Display plot

# %%
# Count of individual penguins in sample
penguins["species"].value_counts()
# Out:
# species
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: count, dtype: int64

# %%
# Penguin by body mass and sex
# Boxplot
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(8,5)) # Plot size
sns.boxplot(data=penguins, x="species", y="body_mass_g", hue="sex", palette="YlGnBu") # species and body mass count split by sex
plt.title("2.Penguin Body Mass by Species and Sex") # Plot title
plt.xlabel("Species") # x-axis label
plt.ylabel("Body Mass (g)") # y-axis label
plt.show() # Display plot

# %%
# Relationship between flipper length and body mass
#scatterplot
plt.figure(figsize=(8,5))

order = ["Chinstrap", "Adelie", "Gentoo"] # List of species
# Flipper length and body mass relations split by species and styled by sex
sns.scatterplot(data=penguins, 
                x="flipper_length_mm", x 
                y="body_mass_g",
                hue="species", 
                hue_order=order,
                style="sex", 
                palette="YlGnBu")
plt.title("3.Relationship Between Flipper Length and Body Mass") # Plot title
plt.xlabel("Flipper Length (mm)") # x-axis label
plt.ylabel("Body Mass (g)")       # y-axis label
plt.show() # Display plot

# %%
# Bill Length vs Bill Depth by Species
# Bill length and bill depth split by species scatterplots and histplots
sns.jointplot(
    data=penguins,
    x="bill_length_mm",
    y="bill_depth_mm",
    hue="species",
    palette="YlGnBu",
    height=6
)

plt.suptitle("4.Bill Length vs Bill Depth by Species", y=1.02) #Plot title (suptitle used with jointplot for clarity)
plt.show() # Display plot

# %%
# Bill Length vs Bill Depth by Species with Trend Lines
# Implot
import seaborn as sns
import matplotlib.pyplot as plt

# Bill length and depth with scatterplot and trend lines
sns.lmplot(
    data=penguins,
    x="bill_length_mm",
    y="bill_depth_mm",
    hue="species",
    palette="YlGnBu",
    height=6,
    markers=["o", "s", "D"],  # species markers
    ci=None                   # removes confidence interval shading
)

plt.title("5.Bill Length vs Bill Depth by Species with Trend Lines") # Plot title
plt.xlabel("Bill Length (mm)") # x-axis label
plt.ylabel("Bill Depth (mm)")  # y-axis label
plt.show() # Display plot

# %%
# Correlation Between Penguin Measurements
#Heatmap
import seaborn as sns
import matplotlib.pyplot as plt

# Numeric columns 
numeric_cols = ["bill_length_mm", "bill_depth_mm", "flipper_length_mm", "body_mass_g"]
penguin_numeric = penguins[numeric_cols]

# Correlate data columns
corr = penguin_numeric.corr()

# Plot heatmap
plt.figure(figsize=(6,5)) # Plot size
sns.heatmap(corr, annot=True, cmap="YlGnBu", fmt=".2f") # Heatmap correlation mattrix(DataFrame), numbers in cells, colour map, format to 2 decimal places 
plt.title("6.Correlation Between Penguin Measurements") #Plot title
plt.show() # Display plot
